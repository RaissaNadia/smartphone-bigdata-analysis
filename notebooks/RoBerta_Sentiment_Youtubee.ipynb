# %% [markdown]
# # ROBERTA SENTIMENT

# %%
# !pip install -q transformers torch tqdm

# %%
import pandas as pd
import numpy as np
import torch

from tqdm import tqdm
from transformers import pipeline

# %%
df = pd.read_csv("Model Rule Based.csv")
df
# Out:
#      Channel_Sumber              Author  \
# 0      Jagat Review    @CheverrlynAdyba
# 1      Jagat Review   @caesarrizkie9742
# 2      Jagat Review       @adealfian664
# 3      Jagat Review         @RsyatLyioz
# 4      Jagat Review          @CitraUtut
# ...             ...                 ...
# 7194       Gadgetin             @imnaps
# 7195       Gadgetin           @MOLEND95
# 7196       Gadgetin  @m.abidalbaqie9527
# 7197       Gadgetin       @tayaaasy8007
# 7198       Gadgetin          @adhapriyo
#
#                                           Comment_Final  Likes  \
# 0                               link beli chamon pro 5g      0
# 1     ngomongin rog kah kamera turun lihat review ca...      0
# 2     user samsung one ui ui enak ui ui if you can t...      0
# 3                                   tecno pova ultra 5g      0
# 4                     tolong buatin rekomendasi lebaran      2
# ...                                                 ...    ...
# 7194                              akhirnyaa rekomendasi      1
# 7195                                       first wkwkkw      0
# 7196                          party popper party popper      0
# 7197  sampe skrng kebel loudly crying face loudly cr...      0
# 7198                  pin mass grinning face with sweat      2
#
#                            Time Tipe_Komentar Sentiment_Rule
# 0     2026-03-21 13:04:52+00:00         Utama         Netral
# 1     2026-03-17 20:41:02+00:00         Utama        Positif
# 2     2026-03-13 23:27:54+00:00         Utama         Netral
# 3     2026-03-12 20:11:30+00:00         Utama         Netral
# 4     2026-03-02 23:12:23+00:00         Utama        Positif
# ...                         ...           ...            ...
# 7194  2025-12-07 09:27:42+00:00         Utama        Positif
# 7195  2025-12-07 09:27:40+00:00         Utama         Netral
# 7196  2025-12-07 09:27:40+00:00         Utama         Netral
# 7197  2025-12-07 09:27:39+00:00         Utama         Netral
# 7198  2025-12-07 09:27:30+00:00         Utama         Netral
#
# [7199 rows x 7 columns]

# %%
df.columns.tolist()
# Out:
# ['Channel_Sumber',
#  'Author',
#  'Comment_Final',
#  'Likes',
#  'Time',
#  'Tipe_Komentar',
#  'Sentiment_Rule']

# %%
device = 0 if torch.cuda.is_available() else -1
print("Device:", device)
# Out:
# Device: -1

# %% [markdown]
# ## Load Model RoBerta

# %%
model = pipeline(
    "sentiment-analysis",
    model="w11wo/indonesian-roberta-base-sentiment-classifier"
)

print("Model berhasil di-load")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/328 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/808k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/467k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.38M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Model berhasil di-load

# %%
model("kamera bagus banget")
# Out:
# [{'label': 'positive', 'score': 0.9956856966018677}]

# %% [markdown]
# ## Prediksi Batch

# %%
from tqdm import tqdm
import torch

device = 0 if torch.cuda.is_available() else -1

komentar = (
    df["Comment_Final"]
    .astype(str)
    .fillna("")
    .tolist()
)

# %%
hasil = []

batch_size = 32

for i in tqdm(range(0, len(komentar), batch_size)):

    batch = komentar[i:i+batch_size]

    pred = model(
        batch,
        truncation=True,
        max_length=512
    )

    hasil.extend(
        [x["label"] for x in pred]
    )

df["Sentiment_Roberta"] = hasil

print("✅ Prediksi selesai")
# Out:
# 100%|██████████| 225/225 [12:22<00:00,  3.30s/it]
# ✅ Prediksi selesai

# %%
df[
    ["Comment_Final","Sentiment_Roberta"]
].sample(10)
# Out:
#                                           Comment_Final Sentiment_Roberta
# 500                             bahas kamera stabilitas           neutral
# 1183  gapapa biar murah moto masuk bagus saing kelas...           neutral
# 5868  ambil poco x7pro sinyal gaming n storage kamer...           neutral
# 2541  rekomendasi beli handphone samsung harga 3jtaa...           neutral
# 6987                            xiaomi 15t pro 1tb beli           neutral
# 3852              vivo x300 pro find x9 pro all rounder           neutral
# 2305                           terima kasih rekomendasi          positive
# 3835  banget stok hpnya hpnya aja kerja hpku lambat ...          negative
# 5421                   team lihat beli kaga crying face          negative
# 1141  tunggu ken banget iqoo bingung bagus 3jtan sem...          negative

# %%
df["Sentiment_Roberta"].value_counts()
# Out:
# Sentiment_Roberta
# neutral     4214
# negative    1663
# positive    1322
# Name: count, dtype: int64

# %% [markdown]
# ## Ubah label Inggris → Indonesia

# %%
map_label = {
    "positive": "Positif",
    "negative": "Negatif",
    "neutral": "Netral"
}

df["Sentiment_Roberta"] = (
    df["Sentiment_Roberta"]
    .replace(map_label)
)

# %%
df[["Comment_Final","Sentiment_Rule","Sentiment_Roberta"]].sample(10)
# Out:
#                                           Comment_Final Sentiment_Rule  \
# 4837                   lohh tunggu david fire fire fire         Netral
# 3514                                     bahas poco c85         Netral
# 4348  tahan iphone ultra pro max crying face smiling...        Positif
# 679                        realme p3 beneran ois realme         Netral
# 1264                beli murni audiojack snapdragon gen         Netral
# 592            izin koreksi tau poco f6 ip rating menit         Netral
# 3353                 handphone ip pro max uda subscribe         Netral
# 6125      pakai infinix hot 4g buruk xosnya ngebug aman        Negatif
# 2964  mohon doa moga kebel handphone doa orang insya...        Positif
# 3247    ngikutin ganti handphone face with tears of joy         Netral
#
#      Sentiment_Roberta
# 4837           Negatif
# 3514            Netral
# 4348            Netral
# 679            Positif
# 1264            Netral
# 592             Netral
# 3353            Netral
# 6125           Negatif
# 2964           Positif
# 3247            Netral

# %% [markdown]
# ## Crosstab Rule vs RoBERTa

# %%
ct = pd.crosstab(
    df["Sentiment_Rule"],
    df["Sentiment_Roberta"]
)

display(ct)
# Out:
# Sentiment_Roberta  Negatif  Netral  Positif
# Sentiment_Rule
# Negatif                137      53       24
# Netral                1329    3589      561
# Positif                197     572      737

# %%
ct_percent = pd.crosstab(
    df["Sentiment_Rule"],
    df["Sentiment_Roberta"],
    normalize="index"
) * 100

ct_final = (
    ct.astype(str)
    + " ("
    + ct_percent.round(1).astype(str)
    + "%)"
)

display(ct_final)
# Out:
# Sentiment_Roberta       Negatif        Netral      Positif
# Sentiment_Rule
# Negatif             137 (64.0%)    53 (24.8%)   24 (11.2%)
# Netral             1329 (24.3%)  3589 (65.5%)  561 (10.2%)
# Positif             197 (13.1%)   572 (38.0%)  737 (48.9%)

# %% [markdown]
# ## Distribusi Sentimen

# %%
print("=== RULE BASED ===")
display(df["Sentiment_Rule"].value_counts())
# Out:
# === RULE BASED ===
# Sentiment_Rule
# Netral     5479
# Positif    1506
# Negatif     214
# Name: count, dtype: int64

# %%
print("=== ROBERTA ===")
display(df["Sentiment_Roberta"].value_counts())
# Out:
# === ROBERTA ===
# Sentiment_Roberta
# Netral     4214
# Negatif    1663
# Positif    1322
# Name: count, dtype: int64

# %%
df.to_csv(
    "Youtube Sentiment_Roberta.csv",
    index=False,
    encoding="utf-8-sig")

print("Youtube Sentiment_Roberta.csv tersimpan")
# Out:
# Youtube Sentiment_Roberta.csv tersimpan
